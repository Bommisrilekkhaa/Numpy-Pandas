# %% [markdown]
# <a href="https://colab.research.google.com/github/Bommisrilekkhaa/Pandas/blob/main/pandas_beginner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
a=np.array([1,2,3,4,5])

# %%
type(a)
# Out:
# numpy.ndarray

# %%
s=pd.Series([1,2,3,4,5])
type(s)
# Out:
# pandas.core.series.Series

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s[3]
# Out:
# 4

# %%
s.drop(3) ##no index change
# Out:
# 0    1
# 1    2
# 2    3
# 4    5
# dtype: int64

# %%
s[3]
# Out:
# 4

# %%
s.drop(3,inplace=True)

# %%
s.iloc[3] #current position index
# Out:
# 5

# %%
s.loc[4] #index in creating
# Out:
# 5

# %%
s
# Out:
# 0    1
# 1    2
# 2    3
# 4    5
# dtype: int64

# %%
s.index
# Out:
# Int64Index([0, 1, 2, 4], dtype='int64')

# %%
ss=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
ss
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
data=[['alex',23,'20-10-2003'],['bob',24,None],['azad',28,'10-9-2001']]

# %%
data
# Out:
# [['alex', 23, '20-10-2003'], ['bob', 24, None], ['azad', 28, '10-9-2001']]

# %%
df=pd.DataFrame(data)
df
# Out:
#       0   1           2
# 0  alex  23  20-10-2003
# 1   bob  24        None
# 2  azad  28   10-9-2001

# %%
df[0][0]
# Out:
# 'alex'

# %%
df[[0,2]]
# Out:
#       0           2
# 0  alex  20-10-2003
# 1   bob        None
# 2  azad   10-9-2001

# %%
df=pd.DataFrame(data,columns=['name','age','dob'])
df
# Out:
#    name  age         dob
# 0  alex   23  20-10-2003
# 1   bob   24        None
# 2  azad   28   10-9-2001

# %%
df.loc[0,'name']
# Out:
# 'alex'

# %%
df.iloc[0,0]
# Out:
# 'alex'

# %%
df.iloc[0][0]
# Out:
# 'alex'

# %%
df.loc[0] #slicing end index inclusive
# Out:
# name          alex
# age             23
# dob     20-10-2003
# Name: 0, dtype: object

# %%
df[0:1]
# Out:
#    name  age         dob
# 0  alex   23  20-10-2003

# %%
s=pd.Series([1,2,3])
s
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s.plot() #direct plotting
# Out:
# <Axes: >

# %%
s.hist(bins=100)
# Out:
# <Axes: >

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s1=s.to_numpy()
s1
# Out:
# array([1, 2, 3])

# %%
type(s1)
# Out:
# numpy.ndarray

# %%
df
# Out:
#    name  age         dob
# 0  alex   23  20-10-2003
# 1   bob   24        None
# 2  azad   28   10-9-2001

# %%
df.head()
# Out:
#    name  age         dob
# 0  alex   23  20-10-2003
# 1   bob   24        None
# 2  azad   28   10-9-2001

# %%
df.tail(1)
# Out:
#    name  age        dob
# 2  azad   28  10-9-2001

# %%
#None ''  '-' '?' 'Nil'  np.nan  (Not a Number)

# %%
df.isnull().sum()
# Out:
# name    0
# age     0
# dob     1
# dtype: int64

# %%
df.dropna()
df
# Out:
#    name  age         dob
# 0  alex   23  20-10-2003
# 1   bob   24        None
# 2  azad   28   10-9-2001

# %%
#df.drop? #help manual

# %%
df.drop(['age'],axis=1,inplace=True)
df
# Out:
#    name         dob
# 0  alex  20-10-2003
# 1   bob        None
# 2  azad   10-9-2001

# %%
df.drop([0,2])
# Out:
#   name   dob
# 1  bob  None

# %%
a
# Out:
# array([1, 2, 3, 4, 5])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   dob     2 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
df['name'].str.contains('b')
# Out:
# 0    False
# 1     True
# 2    False
# Name: name, dtype: bool

# %%
print('e' in df['name'])
# Out:
# False

# %%
print(df.shape)
print(df.size)
print(df.axes)
print(df.ndim)
print(df.dtypes)
print(df.index)
print(df.columns)
print(df.values)
# Out:
# (3, 2)
# 6
# [RangeIndex(start=0, stop=3, step=1), Index(['name', 'dob'], dtype='object')]
# 2
# name    object
# dob     object
# dtype: object
# RangeIndex(start=0, stop=3, step=1)
# Index(['name', 'dob'], dtype='object')
# [['alex' '20-10-2003']
#  ['bob' None]
#  ['azad' '10-9-2001']]

# %%
df
# Out:
#    name         dob
# 0  alex  20-10-2003
# 1   bob        None
# 2  azad   10-9-2001

# %%
df['dob'][1]='19-8-2003'

# %%
df
# Out:
#    name         dob
# 0  alex  20-10-2003
# 1   bob   19-8-2003
# 2  azad   10-9-2001

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_science_fiction_novels')
df
# Out:
# [    0                                                  1
#  0 NaN  This literature-related list is incomplete; yo...,
#     .mw-parser-output .navbar{display:inline;font-size:88%;font-weight:normal}.mw-parser-output .navbar-collapse{float:left;text-align:left}.mw-parser-output .navbar-boxtext{word-spacing:0}.mw-parser-output .navbar ul{display:inline-block;white-space:nowrap;line-height:inherit}.mw-parser-output .navbar-brackets::before{margin-right:-0.125em;content:"[ "}.mw-parser-output .navbar-brackets::after{margin-left:-0.125em;content:" ]"}.mw-parser-output .navbar li{word-spacing:-0.125em}.mw-parser-output .navbar a>span,.mw-parser-output .navbar a>abbr{text-decoration:inherit}.mw-parser-output .navbar-mini abbr{font-variant:small-caps;border-bottom:none;text-decoration:none;cursor:inherit}.mw-parser-output .navbar-ct-full{font-size:114%;margin:0 7em}.mw-parser-output .navbar-ct-mini{font-size:114%;margin:0 4em}vteScience fiction  \
# ...

# %%
#df.describe()

# %%
df=pd.read_table("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/chipotle.tsv")
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
type(df.item_name)
# Out:
# pandas.core.series.Series

# %%
type(df['item_price'])
# Out:
# pandas.core.series.Series

# %%
df.item_price=df.item_price.str.replace('$','')
# Out:
# <ipython-input-56-20961e8be3c3>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df.item_price=df.item_price.str.replace('$','')

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# ...

# %%
df.item_price=df.item_price.astype(np.float64)

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df['item_price']*2
# Out:
# 0        4.78
# 1        6.78
# 2        6.78
# 3        4.78
# 4       33.96
#         ...
# 4617    23.50
# 4618    23.50
# 4619    22.50
# 4620    17.50
# 4621    17.50
# Name: item_price, Length: 4622, dtype: float64

# %%
df.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# ...

# %%
df.item_name.unique
# Out:
# <bound method Series.unique of 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object>

# %%
df.drink=df[df.item_price<2.2]
# Out:
# <ipython-input-63-18ac344db8dd>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.drink=df[df.item_price<2.2]

# %%
df.drink
# Out:
#       order_id  quantity          item_name choice_description  item_price
# 6            3         1      Side of Chips                NaN        1.69
# 18           9         2        Canned Soda           [Sprite]        2.18
# 28          14         1        Canned Soda       [Dr. Pepper]        1.09
# 32          16         1      Side of Chips                NaN        1.69
# 34          17         1      Bottled Water                NaN        1.09
# ...        ...       ...                ...                ...         ...
# 4601      1827         1  Canned Soft Drink        [Diet Coke]        1.25
# 4606      1828         1  Canned Soft Drink             [Coke]        1.25
# 4609      1829         1  Canned Soft Drink           [Sprite]        1.25
# 4613      1831         1              Chips                NaN        2.15
# 4614      1831         1      Bottled Water                NaN        1.50
#
# [801 rows x 5 columns]

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN        2.39
# ...

# %%
df.drink.item_name.nunique()
# Out:
# 5

# %%
df.drink.item_name.value_counts()
# Out:
# Canned Soft Drink    264
# Chips                193
# Bottled Water        142
# Canned Soda          103
# Side of Chips         99
# Name: item_name, dtype: int64

# %%
df[df.item_name=='Chicken Bowl']
# Out:
#       order_id  quantity     item_name  \
# 4            2         2  Chicken Bowl
# 5            3         1  Chicken Bowl
# 13           7         1  Chicken Bowl
# 19          10         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# ...        ...       ...           ...
# 4590      1825         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 19    [Tomatillo Red Chili Salsa, [Fajita Vegetables...        8.75
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# ...                                                 ...         ...
# ...

# %%
df[df.item_name=='Steak Burrito'].choice_description.value_counts()
# Out:
# [Fresh Tomato Salsa (Mild), [Pinto Beans, Rice, Cheese, Sour Cream]]                                                        12
# [Roasted Chili Corn Salsa (Medium), [Rice, Fajita Veggies, Cheese, Sour Cream, Lettuce]]                                     6
# [Tomatillo Green Chili Salsa, [Fajita Vegetables, Rice, Cheese, Sour Cream, Lettuce]]                                        6
# [[Roasted Chili Corn Salsa (Medium), Tomatillo-Red Chili Salsa (Hot)], [Black Beans, Rice, Cheese, Sour Cream, Lettuce]]     5
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                            5
#                                                                                                                             ..
# [Fresh Tomato Salsa, [Rice, Fajita Vegetables, Black Beans, Sour Cream, Cheese, Lettuce]]                                    1
# ...

# %%
df.item_name
# Out:
# 0                Chips and Fresh Tomato Salsa
# 1                                        Izze
# 2                            Nantucket Nectar
# 3       Chips and Tomatillo-Green Chili Salsa
# 4                                Chicken Bowl
#                         ...
# 4617                            Steak Burrito
# 4618                            Steak Burrito
# 4619                       Chicken Salad Bowl
# 4620                       Chicken Salad Bowl
# 4621                       Chicken Salad Bowl
# Name: item_name, Length: 4622, dtype: object

# %%
df[df.item_name=='Steak Burrito'].choice_description.nunique()
# Out:
# 251

# %%
df.dropna(inplace=True)

# %%
df.choice_description
# Out:
# 1                                            [Clementine]
# 2                                                 [Apple]
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
#                               ...
# 4617    [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...
# 4618    [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...
# 4619    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# 4620    [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...
# 4621    [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...
# Name: choice_description, Length: 3376, dtype: object

# %%
df[df.choice_description.str.contains("Black Beans")].item_name
# Out:
# 4               Chicken Bowl
# 7              Steak Burrito
# 9              Steak Burrito
# 11      Chicken Crispy Tacos
# 12        Chicken Soft Tacos
#                 ...
# 4604            Chicken Bowl
# 4608          Veggie Burrito
# 4611          Veggie Burrito
# 4612           Carnitas Bowl
# 4617           Steak Burrito
# Name: item_name, Length: 1345, dtype: object

# %%
df[df.choice_description.str.contains("Black Beans")].item_name.value_counts()
# Out:
# Chicken Bowl             386
# Chicken Burrito          282
# Steak Burrito            148
# Steak Bowl               110
# Veggie Bowl               60
# Veggie Burrito            55
# Chicken Salad Bowl        49
# Carnitas Bowl             39
# Barbacoa Bowl             37
# Barbacoa Burrito          30
# Carnitas Burrito          28
# Chicken Soft Tacos        19
# Chicken Crispy Tacos      14
# Veggie Salad Bowl         13
# Steak Salad Bowl          13
# Steak Soft Tacos          10
# Carnitas Soft Tacos        7
# Chicken Salad              7
# Veggie Soft Tacos          6
# Barbacoa Soft Tacos        6
# Veggie Salad               5
# Barbacoa Salad Bowl        4
# Barbacoa Crispy Tacos      3
# Carnitas Crispy Tacos      3
# Carnitas Salad Bowl        3
# Steak Crispy Tacos         2
# Steak Salad                2
# Salad                      2
# Burrito                    1
# Carnitas Salad             1
# Name: item_name, dtype: int64

# %%
df[(df.item_price < 10) & (df.item_name=='Chicken Bowl')].sort_values(["item_price","quantity"])
# Out:
#       order_id  quantity     item_name  \
# 2918      1160         1  Chicken Bowl
# 3101      1237         1  Chicken Bowl
# 3664      1466         1  Chicken Bowl
# 26          13         1  Chicken Bowl
# 160         73         1  Chicken Bowl
# ...        ...       ...           ...
# 4583      1823         1  Chicken Bowl
# 4591      1825         1  Chicken Bowl
# 4595      1826         1  Chicken Bowl
# 4599      1827         1  Chicken Bowl
# 4604      1828         1  Chicken Bowl
#
#                                      choice_description  item_price
# 2918  [Fresh Tomato (Mild), [Rice, Sour Cream, Cheese]]        8.19
# 3101  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 3664  [Fresh Tomato (Mild), [Lettuce, Fajita Veggies...        8.19
# 26    [Roasted Chili Corn Salsa (Medium), [Pinto Bea...        8.49
# 160   [Fresh Tomato Salsa (Mild), [Black Beans, Rice...        8.49
# ...                                                 ...         ...
# ...

# %%
df
# Out:
#       order_id  quantity           item_name  \
# 1            1         1                Izze
# 2            1         1    Nantucket Nectar
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# ...        ...       ...                 ...
# 4617      1833         1       Steak Burrito
# 4618      1833         1       Steak Burrito
# 4619      1834         1  Chicken Salad Bowl
# 4620      1834         1  Chicken Salad Bowl
# 4621      1834         1  Chicken Salad Bowl
#
#                                      choice_description  item_price
# 1                                          [Clementine]        3.39
# 2                                               [Apple]        3.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# ...

# %%
mv=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/imdb_1000.csv")
mv
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
mv[(mv.star_rating > 8) & (mv.content_rating == "PG-13")].sort_values(["duration"])
# Out:
#      star_rating                                              title  \
# 175          8.2                                      Touch of Evil
# 232          8.1                                  Chungking Express
# 279          8.1                    The Perks of Being a Wallflower
# 191          8.2                                    The Sixth Sense
# 286          8.1                  The Diving Bell and the Butterfly
# 209          8.1                                 The Imitation Game
# 240          8.1                               The Bourne Ultimatum
# 25           8.6                                  Life Is Beautiful
# 196          8.1                            Guardians of the Galaxy
# 180          8.2                                       Hotel Rwanda
# 73           8.4                            Jodaeiye Nader az Simin
# 260          8.1                                     The Sea Inside
# 118          8.3                 Indiana Jones and the Last Crusade
# ...

# %%
mv[mv.actors_list.str.contains("u'Leonardo DiCaprio")].sort_values(["star_rating","duration"],ascending=(False,True))
# Out:
#      star_rating                        title content_rating      genre  \
# 11           8.8                    Inception          PG-13     Action
# 49           8.5                 The Departed              R      Crime
# 59           8.5             Django Unchained              R    Western
# 143          8.2      The Wolf of Wall Street              R  Biography
# 244          8.1               Shutter Island              R    Mystery
# 340          8.0          Catch Me If You Can          PG-13  Biography
# 309          8.0                Blood Diamond              R  Adventure
# 562          7.8  What's Eating Gilbert Grape          PG-13      Drama
# 620          7.7                      Titanic          PG-13      Drama
# 828          7.5            Gangs of New York              R      Crime
# 888          7.5                  The Aviator          PG-13  Biography
#
#      duration                                        actors_list
# ...

# %%
dt=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/ufo.csv")
dt
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
dt.dropna(subset=['City','Shape Reported'],how='any').shape
# Out:
# (15576, 5)

# %%
dt.dropna(subset=['City','Shape Reported'],how='any')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18234              Capitola             NaN       TRIANGLE    CA
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
dt.dropna(subset=['City','Shape Reported'],how='all').shape
# Out:
# (18237, 5)

# %%
dt.dropna(subset=['City','Shape Reported'],how='all')
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# ...

# %%
dt['Shape Reported'].value_counts()
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# FLARE           1
# HEXAGON         1
# Name: Shape Reported, dtype: int64

# %%
dt['Shape Reported'].isnull().sum()
# Out:
# 2644

# %%
import pandas as pd
d=pd.read_csv("https://raw.githubusercontent.com/nunnarilabs/ml/master/pandas/drinks.csv")
d
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 0    Afghanistan              0                0              0
# 1        Albania             89              132             54
# 2        Algeria             25                0             14
# 3        Andorra            245              138            312
# 4         Angola            217               57             45
# ..           ...            ...              ...            ...
# 188    Venezuela            333              100              3
# 189      Vietnam            111                2              1
# 190        Yemen              6                0              0
# 191       Zambia             32               19              4
# 192     Zimbabwe             64               18              4
#
#      total_litres_of_pure_alcohol      continent
# 0                             0.0           Asia
# 1                             4.9         Europe
# ...

# %%
d[d.continent == "Asia"].beer_servings.agg(['mean','min','max'])
# Out:
# mean     37.045455
# min       0.000000
# max     247.000000
# Name: beer_servings, dtype: float64

# %%
d.groupby("continent").beer_servings
d.groupby("continent").beer_servings.min()
# Out:
# continent
# Africa            0
# Asia              0
# Europe            0
# North America     1
# Oceania           0
# South America    93
# Name: beer_servings, dtype: int64

# %%
d.groupby("continent").beer_servings.agg(['mean','min','max'])
# Out:
#                      mean  min  max
# continent
# Africa          61.471698    0  376
# Asia            37.045455    0  247
# Europe         193.777778    0  361
# North America  145.434783    1  285
# Oceania         89.687500    0  306
# South America  175.083333   93  333
